# %%
# Import necessary libraries
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
import glob
import shutil
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# Define the path for train and test images
data_dir_train = pathlib.Path('Train')  # Adjust the path if needed
data_dir_test = pathlib.Path('Test')    # Adjust the path if needed

# Count the number of images in train and test directories
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print("Total training images:", image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print("Total testing images:", image_count_test)

# Define batch size and image dimensions
batch_size = 32
img_height = 180
img_width = 180

# Create training dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    validation_split=0.2,
    subset='training',
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size
)

# Create validation dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    validation_split=0.2,
    subset='validation',
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size
)

# Get class names
class_names = train_ds.class_names
print("Class names:", class_names)

# Visualize one instance of each class
plt.figure(figsize=(10, 10))
for i, class_name in enumerate(class_names):
    class_dir = data_dir_train / class_name
    image_path = list(class_dir.glob('*.jpg'))[0]
    img = keras.preprocessing.image.load_img(image_path, target_size=(img_height, img_width))
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(img)
    plt.title(class_name)
    plt.axis("off")
plt.tight_layout()
plt.show()

# Cache and prefetch datasets for performance
AUTOTUNE = tf.data.AUTOTUNE  # Updated for newer TensorFlow versions
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# Create the initial model without data augmentation
num_classes = len(class_names)

model = Sequential([
    layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),  # Updated here
    layers.Conv2D(32, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(128, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(num_classes)
])

# Compile the model with appropriate optimizer and loss function
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# View the model summary
model.summary()

# Train the model for 20 epochs
epochs = 20
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs
)

# Visualize training results
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy (Initial Model)')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss (Initial Model)')
plt.show()

# Findings:
# From the training and validation curves, we can observe whether the model is overfitting or underfitting.
# If the training accuracy is significantly higher than validation accuracy, and validation loss increases, it's overfitting.

# Apply data augmentation to reduce overfitting or underfitting
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal_and_vertical"),  # Updated here
        layers.RandomRotation(0.2),
        layers.RandomZoom(0.2),
    ]
)

# Visualize the augmentation strategy on one image
for images, _ in train_ds.take(1):
    plt.figure(figsize=(10, 10))
    first_image = images[0]
    for i in range(9):
        augmented_image = data_augmentation(tf.expand_dims(first_image, 0))
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_image[0].numpy().astype("uint8"))
        plt.axis("off")
    plt.tight_layout()
    plt.show()

# Create the model with data augmentation and dropout layers
model = Sequential([
    data_augmentation,
    layers.Rescaling(1./255),
    layers.Conv2D(32, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Dropout(0.2),
    layers.Conv2D(64, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Dropout(0.2),
    layers.Conv2D(128, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Dropout(0.2),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(num_classes)
])

# Compile the model with appropriate optimizer and loss function
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# Train the model for 20 epochs
epochs = 20
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs
)

# Visualize training results after data augmentation
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy (After Data Augmentation)')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss (After Data Augmentation)')
plt.show()

# Findings:
# Check if the overfitting has reduced after applying data augmentation and dropout.

# Examine the class distribution in the training dataset
train_dir = 'Train'

class_counts = {}
for class_name in class_names:
    dir = os.path.join(train_dir, class_name)
    count = len(glob.glob(os.path.join(dir, '*.jpg')))
    class_counts[class_name] = count

print("Class counts before augmentation:", class_counts)

# Identify classes with least samples and classes that dominate
least_samples_class = min(class_counts, key=class_counts.get)
most_samples_class = max(class_counts, key=class_counts.get)
print(f"Class with least samples: {least_samples_class} ({class_counts[least_samples_class]} images)")
print(f"Class with most samples: {most_samples_class} ({class_counts[most_samples_class]} images)")

# Install Augmentor library
# !pip install Augmentor

# Rectify class imbalances using Augmentor
import Augmentor

# Create augmented images to have at least 500 samples per class
for class_name in class_names:
    class_dir = os.path.join(train_dir, class_name)
    p = Augmentor.Pipeline(class_dir)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.flip_left_right(probability=0.5)
    p.zoom_random(probability=0.5, percentage_area=0.9)
    # Calculate number of samples to generate to reach 500 images per class
    current_count = class_counts[class_name]
    samples_to_generate = 500 - current_count if 500 > current_count else 0
    if samples_to_generate > 0:
        p.sample(samples_to_generate)

# Update class counts after augmentation
class_counts_after = {}
for class_name in class_names:
    dir = os.path.join(train_dir, class_name)
    count = len(glob.glob(os.path.join(dir, '*.jpg')))
    class_counts_after[class_name] = count

print("Class counts after augmentation:", class_counts_after)

# Create new training and validation datasets including augmented images
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    validation_split=0.2,
    subset='training',
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    validation_split=0.2,
    subset='validation',
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size
)

# Cache and prefetch datasets
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# Create the model (with normalization and dropout)
model = Sequential([
    layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),  # Updated here
    layers.Conv2D(32, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Dropout(0.3),
    layers.Conv2D(64, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Dropout(0.3),
    layers.Conv2D(128, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Dropout(0.3),
    layers.Flatten(),
    layers.Dense(256, activation='relu'),
    layers.Dense(num_classes)
])

# Compile the model with appropriate optimizer and loss function
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# Train the model for 30 epochs
epochs = 30
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs
)

# Visualize training results after handling class imbalance
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy (After Handling Class Imbalance)')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss (After Handling Class Imbalance)')
plt.show()

# Analyze your results here
# After handling class imbalance, observe if the model's performance has improved.
# Check if overfitting has reduced and if the validation accuracy has increased.
# Out:
# Total training images: 2239
# Total testing images: 118
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.
# Class names: ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']
# /home/s/.local/lib/python3.12/site-packages/keras/src/layers/preprocessing/tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 180, 180, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 90, 90, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 90, 90, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 45, 45, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 45, 45, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 22, 22, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 61952)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     7,929,984 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 9)              │         1,161 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,024,393 (30.61 MB)
#  Trainable params: 8,024,393 (30.61 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 
# Epoch 7/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 49s 880ms/step - accuracy: 0.4476 - loss: 1.5125 - val_accuracy: 0.4765 - val_loss: 1.5240
# Epoch 8/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 49s 877ms/step - accuracy: 0.4860 - loss: 1.4591 - val_accuracy: 0.5101 - val_loss: 1.4373
# Epoch 9/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 49s 871ms/step - accuracy: 0.4909 - loss: 1.4111 - val_accuracy: 0.5056 - val_loss: 1.4347
# Epoch 10/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 49s 875ms/step - accuracy: 0.5021 - loss: 1.4290 - val_accuracy: 0.5324 - val_loss: 1.3664
# Epoch 11/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 49s 880ms/step - accuracy: 0.5390 - loss: 1.3028 - val_accuracy: 0.5324 - val_loss: 1.3318
# Epoch 12/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 49s 872ms/step - accuracy: 0.4993 - loss: 1.4136 - val_accuracy: 0.5302 - val_loss: 1.3367
# Epoch 13/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 49s 875ms/step - accuracy: 0.5260 - loss: 1.2728 - val_accuracy: 0.5145 - val_loss: 1.3715
# Epoch 14/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 49s 873ms/step - accuracy: 0.5182 - loss: 1.3090 - val_accuracy: 0.5324 - val_loss: 1.3089
# Epoch 15/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 49s 879ms/step - accuracy: 0.5374 - loss: 1.2527 - val_accuracy: 0.5302 - val_loss: 1.3850
# Epoch 16/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 49s 874ms/step - accuracy: 0.5702 - loss: 1.2188 - val_accuracy: 0.5213 - val_loss: 1.3424
# Epoch 17/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 49s 876ms/step - accuracy: 0.5658 - loss: 1.2063 - val_accuracy: 0.5168 - val_loss: 1.4058
# Epoch 18/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 49s 877ms/step - accuracy: 0.5607 - loss: 1.2656 - val_accuracy: 0.5436 - val_loss: 1.3606
# Epoch 19/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 52s 930ms/step - accuracy: 0.5181 - loss: 1.3251 - val_accuracy: 0.5414 - val_loss: 1.3423
# Epoch 20/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 49s 882ms/step - accuracy: 0.5684 - loss: 1.2050 - val_accuracy: 0.5503 - val_loss: 1.3161
# Class counts before augmentation: {'actinic keratosis': 114, 'basal cell carcinoma': 376, 'dermatofibroma': 95, 'melanoma': 438, 'nevus': 357, 'pigmented benign keratosis': 462, 'seborrheic keratosis': 77, 'squamous cell carcinoma': 181, 'vascular lesion': 139}
# Class with least samples: seborrheic keratosis (77 images)
# Class with most samples: pigmented benign keratosis (462 images)
# Requirement already satisfied: Augmentor in /home/s/anaconda3/envs/myenv/lib/python3.12/site-packages (0.2.12)
# Requirement already satisfied: Pillow>=5.2.0 in /home/s/anaconda3/envs/myenv/lib/python3.12/site-packages (from Augmentor) (10.4.0)
# Requirement already satisfied: tqdm>=4.9.0 in /home/s/anaconda3/envs/myenv/lib/python3.12/site-packages (from Augmentor) (4.66.5)
# Requirement already satisfied: numpy>=1.11.0 in /home/s/anaconda3/envs/myenv/lib/python3.12/site-packages (from Augmentor) (1.26.4)
# Initialised with 114 image(s) found.
# Output directory set to Train/actinic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7EBAD03C4800>: 100%|██████████| 386/386 [00:03<00:00, 121.81 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to Train/basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7EBAD3F082C0>: 100%|██████████| 124/124 [00:01<00:00, 116.07 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to Train/dermatofibroma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7EBAD002C530>: 100%|██████████| 405/405 [00:03<00:00, 104.83 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to Train/melanoma/output.
# Processing <PIL.Image.Image image mode=RGB size=2269x1965 at 0x7EBAD80E0740>: 100%|██████████| 62/62 [00:02<00:00, 23.02 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to Train/nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=796x682 at 0x7EBAD8083800>: 100%|██████████| 143/143 [00:05<00:00, 25.04 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to Train/pigmented benign keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7EBAD8081B50>: 100%|██████████| 38/38 [00:00<00:00, 95.08 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to Train/seborrheic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7EBAD0126CC0>: 100%|██████████| 423/423 [00:10<00:00, 41.47 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to Train/squamous cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7EBAD93C9B80>: 100%|██████████| 319/319 [00:03<00:00, 92.18 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to Train/vascular lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7EBAD0DAA0F0>: 100%|██████████| 361/361 [00:03<00:00, 91.81 Samples/s]
# Class counts after augmentation: {'actinic keratosis': 114, 'basal cell carcinoma': 376, 'dermatofibroma': 95, 'melanoma': 438, 'nevus': 357, 'pigmented benign keratosis': 462, 'seborrheic keratosis': 77, 'squamous cell carcinoma': 181, 'vascular lesion': 139}
# Found 4500 files belonging to 9 classes.
# Using 3600 files for training.
# Found 4500 files belonging to 9 classes.
# Using 900 files for validation.
# Epoch 1/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 111s 948ms/step - accuracy: 0.1113 - loss: 3.5183 - val_accuracy: 0.2567 - val_loss: 1.9681
# Epoch 2/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 104s